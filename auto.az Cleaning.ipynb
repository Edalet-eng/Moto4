# %%
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns
import pandas as pd
import numpy as np 
import datetime
import warnings

# %%
pd.set_option('display.max_columns', None)
warnings.filterwarnings(action = 'ignore')

# %%
filepath = 'auto1.csv'
df = pd.read_csv(filepath)
df.head()
# Out:
#       qiymet      şəhər       marka    model  buraxılış ili  ban növü  \
# 0   AZN 9500   Sumqayıt  Volkswagen   Passat           2007     sedan
# 1  AZN 25500       Bakı     Hyundai   Tucson           2012  ofrouder
# 2  AZN 27300       Bakı         Kia  Sorento           2012  ofrouder
# 3  AZN 11500       Bakı        Opel    Astra           2005   xetçbek
# 4  AZN 20500       Bakı        Ford   Fusion           2014     sedan
#
#           rəng      yürüş sürətlər_qutusu ötürücü  mühərrik_hecmi  \
# 0          ağ   336500 km      avtomatik      ön              2.0
# 1          ağ   187000 km      avtomatik      ön              2.0
# 2         göy   145000 km      avtomatik      ön              2.0
# 3      gümüşü   290000 km       mexaniki      ön              1.4
# 4  yaş asfalt   161000 km      avtomatik      ön              2.0
#
#   mühərrik_gucu yanacaq_novu  kredit veziyyeti  \
# 0      200 a.g.       benzin   xeyr       əla
# 1      184 a.g.        dizel   xeyr       əla
# 2      184 a.g.        dizel   xeyr       əla
# 3       90 a.g.       benzin   xeyr     yaxşı
# 4      249 a.g.       benzin   xeyr     yaxşı
#
#                                               tesvir  \
# 0  Avtomobilin ikinci sahibiyəm. Heç bir problemi...
# 1                         Maşın ideal vəziyyətdədir!
# 2  Masinin hec bir problemi yoxdur saz veziyyetde...
# 3  Masin ideal veziyyetdedi ümumi məlumat üçün el...
# 4  Masin polnu fuldu ela veziyyetdedir neise elav...
#
#                                       elave_techizat   yenilendi
# 0  tormozların antiqapanma sistemi (ABS), təhlükə...  27.09.2023
# 1  tormozların antiqapanma sistemi (ABS), təhlükə...  23.08.2023
# 2  tormozların antiqapanma sistemi (ABS), təhlükə...  08.08.2023
# 3  təhlükəsizlik yastıqları, yağış sensoru, duman...  08.08.2023
# 4  tormozların antiqapanma sistemi (ABS), təhlükə...  08.08.2023

# %%
df = df.drop_duplicates()

# %%
df.head()
# Out:
#       qiymet      şəhər       marka    model  buraxılış ili  ban növü  \
# 0   AZN 9500   Sumqayıt  Volkswagen   Passat           2007     sedan
# 1  AZN 25500       Bakı     Hyundai   Tucson           2012  ofrouder
# 2  AZN 27300       Bakı         Kia  Sorento           2012  ofrouder
# 3  AZN 11500       Bakı        Opel    Astra           2005   xetçbek
# 4  AZN 20500       Bakı        Ford   Fusion           2014     sedan
#
#           rəng      yürüş sürətlər_qutusu ötürücü  mühərrik_hecmi  \
# 0          ağ   336500 km      avtomatik      ön              2.0
# 1          ağ   187000 km      avtomatik      ön              2.0
# 2         göy   145000 km      avtomatik      ön              2.0
# 3      gümüşü   290000 km       mexaniki      ön              1.4
# 4  yaş asfalt   161000 km      avtomatik      ön              2.0
#
#   mühərrik_gucu yanacaq_novu  kredit veziyyeti  \
# 0      200 a.g.       benzin   xeyr       əla
# 1      184 a.g.        dizel   xeyr       əla
# 2      184 a.g.        dizel   xeyr       əla
# 3       90 a.g.       benzin   xeyr     yaxşı
# 4      249 a.g.       benzin   xeyr     yaxşı
#
#                                               tesvir  \
# 0  Avtomobilin ikinci sahibiyəm. Heç bir problemi...
# 1                         Maşın ideal vəziyyətdədir!
# 2  Masinin hec bir problemi yoxdur saz veziyyetde...
# 3  Masin ideal veziyyetdedi ümumi məlumat üçün el...
# 4  Masin polnu fuldu ela veziyyetdedir neise elav...
#
#                                       elave_techizat   yenilendi
# 0  tormozların antiqapanma sistemi (ABS), təhlükə...  27.09.2023
# 1  tormozların antiqapanma sistemi (ABS), təhlükə...  23.08.2023
# 2  tormozların antiqapanma sistemi (ABS), təhlükə...  08.08.2023
# 3  təhlükəsizlik yastıqları, yağış sensoru, duman...  08.08.2023
# 4  tormozların antiqapanma sistemi (ABS), təhlükə...  08.08.2023

# %%
df.columns = df.columns.str.replace(pat = ' ', repl = '_')
df.columns = df.columns.str.lower()
df.columns = df.columns.str.strip()
df.head()
# Out:
#       qiymet      şəhər       marka    model  buraxılış_ili  ban_növü  \
# 0   AZN 9500   Sumqayıt  Volkswagen   Passat           2007     sedan
# 1  AZN 25500       Bakı     Hyundai   Tucson           2012  ofrouder
# 2  AZN 27300       Bakı         Kia  Sorento           2012  ofrouder
# 3  AZN 11500       Bakı        Opel    Astra           2005   xetçbek
# 4  AZN 20500       Bakı        Ford   Fusion           2014     sedan
#
#           rəng      yürüş sürətlər_qutusu ötürücü  mühərrik_hecmi  \
# 0          ağ   336500 km      avtomatik      ön              2.0
# 1          ağ   187000 km      avtomatik      ön              2.0
# 2         göy   145000 km      avtomatik      ön              2.0
# 3      gümüşü   290000 km       mexaniki      ön              1.4
# 4  yaş asfalt   161000 km      avtomatik      ön              2.0
#
#   mühərrik_gucu yanacaq_novu  kredit veziyyeti  \
# 0      200 a.g.       benzin   xeyr       əla
# 1      184 a.g.        dizel   xeyr       əla
# 2      184 a.g.        dizel   xeyr       əla
# 3       90 a.g.       benzin   xeyr     yaxşı
# 4      249 a.g.       benzin   xeyr     yaxşı
#
#                                               tesvir  \
# 0  Avtomobilin ikinci sahibiyəm. Heç bir problemi...
# 1                         Maşın ideal vəziyyətdədir!
# 2  Masinin hec bir problemi yoxdur saz veziyyetde...
# 3  Masin ideal veziyyetdedi ümumi məlumat üçün el...
# 4  Masin polnu fuldu ela veziyyetdedir neise elav...
#
#                                       elave_techizat   yenilendi
# 0  tormozların antiqapanma sistemi (ABS), təhlükə...  27.09.2023
# 1  tormozların antiqapanma sistemi (ABS), təhlükə...  23.08.2023
# 2  tormozların antiqapanma sistemi (ABS), təhlükə...  08.08.2023
# 3  təhlükəsizlik yastıqları, yağış sensoru, duman...  08.08.2023
# 4  tormozların antiqapanma sistemi (ABS), təhlükə...  08.08.2023

# %%
def equate(df = None):
    df.sürətlər_qutusu = df.sürətlər_qutusu.str.replace(pat = 'avtomatik', repl = 'avtomat')
    df.ban_növü = df.ban_növü.str.replace(pat = 'ofrouder' , repl = 'offroader / suv')
    df.ban_növü = df.ban_növü.str.replace(pat = 'xetçbek' , repl = 'hetçbek')
    df.ban_növü = df.ban_növü.str.replace(pat = 'miniven/mikroavtobus' , repl = 'minivan')
    df.ban_növü = df.ban_növü.str.replace(pat = 'mototexnika' , repl = 'motosiklet')
    df.ban_növü = df.ban_növü.str.replace(pat = 'xüsusi texnika' , repl = 'yük maşını')
    df.rəng = df.rəng.apply(lambda x: x.replace(' (metallik)',''))
    return df

# %%
def convert_currency(df = None):
    df['qiymet'] = df['qiymet'].apply(lambda x: int(x.replace('$',''))*1.7 if '$' in x else (int(x.replace('€',''))*1.81 if '€' in x else int(x.replace('AZN',''))))
    return df

# %%
def convert_int(df = None):
    df.mühərrik_gucu = df.mühərrik_gucu.str.replace(pat = 'a.g.', repl = '')
    df.yürüş = df.yürüş.str.replace(pat = 'km', repl = '')
    df.yürüş = df.yürüş.str.replace(pat = ' ', repl = '')
    df.mühərrik_hecmi = pd.to_numeric(arg = df.mühərrik_hecmi, downcast = 'float')
    df[['mühərrik_gucu', 'yürüş']] = df[['mühərrik_gucu', 'yürüş']].applymap(func = lambda x: int(x))
    return df

# %%
def convert_lower_case(df = None):
    df_obj = df.select_dtypes(include = 'object') 
    df[df_obj.columns] = df_obj.applymap(lambda x: np.nan if pd.isna(x) else x.lower())
    return df

# %%
def create_new_columns(df = None):
    df['vuruğu_var'] = df.veziyyeti.apply(lambda x: 'vuruğu var' if ' vurulmuş ' in x else 'vuruğu yoxdur')
    df['rənglənib'] = df.veziyyeti.apply(lambda x: 'rənglənib' if ' orta ' in x else 'rənglənməyib')
    df['lehimli_disk'] = df.elave_techizat.apply(lambda x: np.nan if pd.isna(x) else 'var' if 'yüngül lehimli disklər' in x else 'yox')
    df['abs'] = df.elave_techizat.apply(lambda x: np.nan if pd.isna(x) else 'var' if 'abs' in x else 'yox')
    df['lyuk'] = df.elave_techizat.apply(lambda x: np.nan if pd.isna(x) else 'var' if 'lyuk' in x else 'yox')
    df['yağış_sensoru'] = df.elave_techizat.apply(lambda x: np.nan if pd.isna(x) else 'var' if 'yağış sensoru' in x else 'yox')
    df['mərkəzi_qapanma'] = df.elave_techizat.apply(lambda x: np.nan if pd.isna(x) else 'var' if 'mərkəzi qapanma' in x else 'yox')
    df['park_radarı'] = df.elave_techizat.apply(lambda x: np.nan if pd.isna(x) else 'var' if 'park radarı' in x else 'yox')
    df['kondisioner'] = df.elave_techizat.apply(lambda x: np.nan if pd.isna(x) else 'var' if 'kondisioner' in x else 'yox')
    df['oturacaqların_isidilməsi'] = df.elave_techizat.apply(lambda x: np.nan if pd.isna(x) else 'var' if 'qızdırılan oturacaqlar' in x else 'yox')
    df['dəri_salon'] = df.elave_techizat.apply(lambda x: np.nan if pd.isna(x) else 'var' if 'dəri salon' in x else 'yox')
    df['ksenon_lampalar'] = df.elave_techizat.apply(lambda x: np.nan if pd.isna(x) else 'var' if 'ksenon lampalar' in x else 'yox')
    df['arxa_görüntü_kamerası'] = df.elave_techizat.apply(lambda x: np.nan )
    df['yan_pərdələr'] = df.elave_techizat.apply(lambda x: np.nan )
    df['oturacaqların_ventilyasiyası'] = df.elave_techizat.apply(lambda x: np.nan)
    return df

# %%
df = df.pipe(func = convert_currency).pipe(func = convert_int).pipe(func = convert_lower_case).pipe(func = equate).pipe(func = create_new_columns)
df.head()
# Out:
#     qiymet      şəhər       marka    model  buraxılış_ili         ban_növü  \
# 0   9500.0   sumqayıt  volkswagen   passat           2007            sedan
# 1  25500.0       bakı     hyundai   tucson           2012  offroader / suv
# 2  27300.0       bakı         kia  sorento           2012  offroader / suv
# 3  11500.0       bakı        opel    astra           2005          hetçbek
# 4  20500.0       bakı        ford   fusion           2014            sedan
#
#           rəng   yürüş sürətlər_qutusu ötürücü  mühərrik_hecmi  mühərrik_gucu  \
# 0          ağ   336500        avtomat      ön              2.0            200
# 1          ağ   187000        avtomat      ön              2.0            184
# 2         göy   145000        avtomat      ön              2.0            184
# 3      gümüşü   290000       mexaniki      ön              1.4             90
# 4  yaş asfalt   161000        avtomat      ön              2.0            249
#
#   yanacaq_novu  kredit veziyyeti  \
# 0       benzin   xeyr       əla
# 1        dizel   xeyr       əla
# 2        dizel   xeyr       əla
# 3       benzin   xeyr     yaxşı
# 4       benzin   xeyr     yaxşı
#
#                                               tesvir  \
# 0  avtomobilin ikinci sahibiyəm. heç bir problemi...
# 1                         maşın ideal vəziyyətdədir!
# 2  masinin hec bir problemi yoxdur saz veziyyetde...
# 3  masin ideal veziyyetdedi ümumi məlumat üçün el...
# 4  masin polnu fuldu ela veziyyetdedir neise elav...
#
#                                       elave_techizat   yenilendi  \
# 0  tormozların antiqapanma sistemi (abs), təhlükə...  27.09.2023
# 1  tormozların antiqapanma sistemi (abs), təhlükə...  23.08.2023
# 2  tormozların antiqapanma sistemi (abs), təhlükə...  08.08.2023
# 3  təhlükəsizlik yastıqları, yağış sensoru, duman...  08.08.2023
# 4  tormozların antiqapanma sistemi (abs), təhlükə...  08.08.2023
#
#       vuruğu_var     rənglənib lehimli_disk  abs lyuk yağış_sensoru  \
# 0  vuruğu yoxdur  rənglənməyib          var  var  var           yox
# 1  vuruğu yoxdur  rənglənməyib          var  var  yox           yox
# 2  vuruğu yoxdur  rənglənməyib          var  var  yox           var
# 3  vuruğu yoxdur  rənglənməyib          var  yox  yox           var
# 4  vuruğu yoxdur  rənglənməyib          var  var  var           var
#
#   mərkəzi_qapanma park_radarı kondisioner oturacaqların_isidilməsi dəri_salon  \
# 0             var         yox         var                      var        var
# 1             var         var         var                      var        var
# 2             var         var         var                      var        yox
# 3             var         yox         var                      yox        var
# 4             var         var         var                      var        var
#
#   ksenon_lampalar  arxa_görüntü_kamerası  yan_pərdələr  \
# 0             yox                    NaN           NaN
# 1             yox                    NaN           NaN
# 2             var                    NaN           NaN
# 3             yox                    NaN           NaN
# 4             var                    NaN           NaN
#
#    oturacaqların_ventilyasiyası
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN

# %%
df = df.drop(columns = ['veziyyeti','tesvir','elave_techizat'])

# %%
df
# Out:
#       qiymet         şəhər       marka    model  buraxılış_ili  \
# 0     9500.0      sumqayıt  volkswagen   passat           2007
# 1    25500.0          bakı     hyundai   tucson           2012
# 2    27300.0          bakı         kia  sorento           2012
# 3    11500.0          bakı        opel    astra           2005
# 4    20500.0          bakı        ford   fusion           2014
# ..       ...           ...         ...      ...            ...
# 761  12000.0  əlaqəli şəxs  volkswagen    jetta           2009
# 762   7000.0  əlaqəli şəxs   chevrolet     aveo           2010
# 763   7200.0  əlaqəli şəxs  lada (vaz)     niva           2012
# 764   5800.0  əlaqəli şəxs        opel   vectra           1997
# 765   8400.0  əlaqəli şəxs  lada (vaz)     2107           2010
#
#             ban_növü         rəng   yürüş sürətlər_qutusu ötürücü  \
# 0              sedan          ağ   336500        avtomat      ön
# 1    offroader / suv          ağ   187000        avtomat      ön
# 2    offroader / suv         göy   145000        avtomat      ön
# 3            hetçbek      gümüşü   290000       mexaniki      ön
# 4              sedan  yaş asfalt   161000        avtomat      ön
# ..               ...          ...     ...             ...     ...
# 761            sedan  yaş asfalt   300000        avtomat      ön
# 762            sedan          ağ   211000       mexaniki      ön
# 763  offroader / suv          ağ   173000       mexaniki     tam
# 764          hetçbek          ağ   480000        avtomat      ön
# 765            sedan  yaş asfalt    49400       mexaniki    arxa
#
#      mühərrik_hecmi  mühərrik_gucu yanacaq_novu  kredit   yenilendi  \
# 0               2.0            200       benzin   xeyr   27.09.2023
# 1               2.0            184        dizel   xeyr   23.08.2023
# 2               2.0            184        dizel   xeyr   08.08.2023
# 3               1.4             90       benzin   xeyr   08.08.2023
# 4               2.0            249       benzin   xeyr   08.08.2023
# ..              ...            ...          ...     ...         ...
# 761             2.5            170       benzin   xeyr   11.04.2023
# 762             1.4            101       benzin   xeyr   11.04.2023
# 763             1.7             80       benzin   xeyr   11.04.2023
# 764             1.8            115       benzin   xeyr   11.04.2023
# 765             1.6             75       benzin   xeyr   11.04.2023
#
#         vuruğu_var     rənglənib lehimli_disk  abs lyuk yağış_sensoru  \
# 0    vuruğu yoxdur  rənglənməyib          var  var  var           yox
# 1    vuruğu yoxdur  rənglənməyib          var  var  yox           yox
# 2    vuruğu yoxdur  rənglənməyib          var  var  yox           var
# 3    vuruğu yoxdur  rənglənməyib          var  yox  yox           var
# 4    vuruğu yoxdur  rənglənməyib          var  var  var           var
# ..             ...           ...          ...  ...  ...           ...
# 761  vuruğu yoxdur  rənglənməyib          var  var  var           yox
# 762  vuruğu yoxdur     rənglənib          var  var  yox           yox
# 763  vuruğu yoxdur     rənglənib          var  yox  yox           yox
# 764  vuruğu yoxdur     rənglənib          var  var  var           yox
# 765  vuruğu yoxdur  rənglənməyib          yox  yox  yox           var
#
#     mərkəzi_qapanma park_radarı kondisioner oturacaqların_isidilməsi  \
# 0               var         yox         var                      var
# 1               var         var         var                      var
# 2               var         var         var                      var
# 3               var         yox         var                      yox
# 4               var         var         var                      var
# ..              ...         ...         ...                      ...
# 761             var         yox         var                      var
# 762             yox         yox         yox                      yox
# 763             yox         yox         yox                      yox
# 764             yox         yox         yox                      yox
# 765             yox         yox         yox                      yox
#
#     dəri_salon ksenon_lampalar  arxa_görüntü_kamerası  yan_pərdələr  \
# 0          var             yox                    NaN           NaN
# 1          var             yox                    NaN           NaN
# 2          yox             var                    NaN           NaN
# 3          var             yox                    NaN           NaN
# 4          var             var                    NaN           NaN
# ..         ...             ...                    ...           ...
# 761        var             yox                    NaN           NaN
# 762        yox             yox                    NaN           NaN
# 763        yox             var                    NaN           NaN
# 764        yox             yox                    NaN           NaN
# 765        yox             var                    NaN           NaN
#
#      oturacaqların_ventilyasiyası
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ..                            ...
# 761                           NaN
# 762                           NaN
# 763                           NaN
# 764                           NaN
# 765                           NaN
#
# [766 rows x 30 columns]

# %%
filepath = 'soldout.csv'
df1 = pd.read_csv(filepath)
df1.head()
# Out:
#     qiymet      şəhər       marka    model  buraxılış_ili         ban_növü  \
# 0   9500.0   sumqayıt  volkswagen   passat           2007            sedan
# 1  25500.0       bakı     hyundai   tucson           2012  offroader / suv
# 2  27300.0       bakı         kia  sorento           2012  offroader / suv
# 3  11500.0       bakı        opel    astra           2005          hetçbek
# 4  20500.0       bakı        ford   fusion           2014            sedan
#
#           rəng   yürüş sürətlər_qutusu ötürücü  mühərrik_hecmi  mühərrik_gucu  \
# 0          ağ   336500        avtomat      ön              2.0            200
# 1          ağ   187000        avtomat      ön              2.0            184
# 2         göy   145000        avtomat      ön              2.0            184
# 3      gümüşü   290000       mexaniki      ön              1.4             90
# 4  yaş asfalt   161000        avtomat      ön              2.0            249
#
#   yanacaq_novu  kredit   yenilendi     vuruğu_var     rənglənib lehimli_disk  \
# 0       benzin   xeyr   27.09.2023  vuruğu yoxdur  rənglənməyib          var
# 1        dizel   xeyr   23.08.2023  vuruğu yoxdur  rənglənməyib          var
# 2        dizel   xeyr   08.08.2023  vuruğu yoxdur  rənglənməyib          var
# 3       benzin   xeyr   08.08.2023  vuruğu yoxdur  rənglənməyib          var
# 4       benzin   xeyr   08.08.2023  vuruğu yoxdur  rənglənməyib          var
#
#    abs lyuk yağış_sensoru mərkəzi_qapanma park_radarı kondisioner  \
# 0  var  var           yox             var         yox         var
# 1  var  yox           yox             var         var         var
# 2  var  yox           var             var         var         var
# 3  yox  yox           var             var         yox         var
# 4  var  var           var             var         var         var
#
#   oturacaqların_isidilməsi dəri_salon ksenon_lampalar  arxa_görüntü_kamerası  \
# 0                      var        var             yox                    NaN
# 1                      var        var             yox                    NaN
# 2                      var        yox             var                    NaN
# 3                      yox        var             yox                    NaN
# 4                      var        var             var                    NaN
#
#    yan_pərdələr  oturacaqların_ventilyasiyası
# 0           NaN                           NaN
# 1           NaN                           NaN
# 2           NaN                           NaN
# 3           NaN                           NaN
# 4           NaN                           NaN

# %%
merged_data=pd.concat([df,df1])
merged_data
# Out:
#       qiymet         şəhər       marka    model  buraxılış_ili  \
# 0     9500.0      sumqayıt  volkswagen   passat           2007
# 1    25500.0          bakı     hyundai   tucson           2012
# 2    27300.0          bakı         kia  sorento           2012
# 3    11500.0          bakı        opel    astra           2005
# 4    20500.0          bakı        ford   fusion           2014
# ..       ...           ...         ...      ...            ...
# 761  12000.0  əlaqəli şəxs  volkswagen    jetta           2009
# 762   7000.0  əlaqəli şəxs   chevrolet     aveo           2010
# 763   7200.0  əlaqəli şəxs  lada (vaz)     niva           2012
# 764   5800.0  əlaqəli şəxs        opel   vectra           1997
# 765   8400.0  əlaqəli şəxs  lada (vaz)     2107           2010
#
#             ban_növü         rəng   yürüş sürətlər_qutusu ötürücü  \
# 0              sedan          ağ   336500        avtomat      ön
# 1    offroader / suv          ağ   187000        avtomat      ön
# 2    offroader / suv         göy   145000        avtomat      ön
# 3            hetçbek      gümüşü   290000       mexaniki      ön
# 4              sedan  yaş asfalt   161000        avtomat      ön
# ..               ...          ...     ...             ...     ...
# 761            sedan  yaş asfalt   300000        avtomat      ön
# 762            sedan          ağ   211000       mexaniki      ön
# 763  offroader / suv          ağ   173000       mexaniki     tam
# 764          hetçbek          ağ   480000        avtomat      ön
# 765            sedan  yaş asfalt    49400       mexaniki    arxa
#
#      mühərrik_hecmi  mühərrik_gucu yanacaq_novu  kredit   yenilendi  \
# 0               2.0            200       benzin   xeyr   27.09.2023
# 1               2.0            184        dizel   xeyr   23.08.2023
# 2               2.0            184        dizel   xeyr   08.08.2023
# 3               1.4             90       benzin   xeyr   08.08.2023
# 4               2.0            249       benzin   xeyr   08.08.2023
# ..              ...            ...          ...     ...         ...
# 761             2.5            170       benzin   xeyr   11.04.2023
# 762             1.4            101       benzin   xeyr   11.04.2023
# 763             1.7             80       benzin   xeyr   11.04.2023
# 764             1.8            115       benzin   xeyr   11.04.2023
# 765             1.6             75       benzin   xeyr   11.04.2023
#
#         vuruğu_var     rənglənib lehimli_disk  abs lyuk yağış_sensoru  \
# 0    vuruğu yoxdur  rənglənməyib          var  var  var           yox
# 1    vuruğu yoxdur  rənglənməyib          var  var  yox           yox
# 2    vuruğu yoxdur  rənglənməyib          var  var  yox           var
# 3    vuruğu yoxdur  rənglənməyib          var  yox  yox           var
# 4    vuruğu yoxdur  rənglənməyib          var  var  var           var
# ..             ...           ...          ...  ...  ...           ...
# 761  vuruğu yoxdur  rənglənməyib          var  var  var           yox
# 762  vuruğu yoxdur     rənglənib          var  var  yox           yox
# 763  vuruğu yoxdur     rənglənib          var  yox  yox           yox
# 764  vuruğu yoxdur     rənglənib          var  var  var           yox
# 765  vuruğu yoxdur  rənglənməyib          yox  yox  yox           var
#
#     mərkəzi_qapanma park_radarı kondisioner oturacaqların_isidilməsi  \
# 0               var         yox         var                      var
# 1               var         var         var                      var
# 2               var         var         var                      var
# 3               var         yox         var                      yox
# 4               var         var         var                      var
# ..              ...         ...         ...                      ...
# 761             var         yox         var                      var
# 762             yox         yox         yox                      yox
# 763             yox         yox         yox                      yox
# 764             yox         yox         yox                      yox
# 765             yox         yox         yox                      yox
#
#     dəri_salon ksenon_lampalar  arxa_görüntü_kamerası  yan_pərdələr  \
# 0          var             yox                    NaN           NaN
# 1          var             yox                    NaN           NaN
# 2          yox             var                    NaN           NaN
# 3          var             yox                    NaN           NaN
# 4          var             var                    NaN           NaN
# ..         ...             ...                    ...           ...
# 761        var             yox                    NaN           NaN
# 762        yox             yox                    NaN           NaN
# 763        yox             var                    NaN           NaN
# 764        yox             yox                    NaN           NaN
# 765        yox             var                    NaN           NaN
#
#      oturacaqların_ventilyasiyası
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ..                            ...
# 761                           NaN
# 762                           NaN
# 763                           NaN
# 764                           NaN
# 765                           NaN
#
# [1532 rows x 30 columns]

# %%
merged_data.drop_duplicates()
# Out:
#       qiymet         şəhər       marka    model  buraxılış_ili  \
# 0     9500.0      sumqayıt  volkswagen   passat           2007
# 1    25500.0          bakı     hyundai   tucson           2012
# 2    27300.0          bakı         kia  sorento           2012
# 3    11500.0          bakı        opel    astra           2005
# 4    20500.0          bakı        ford   fusion           2014
# ..       ...           ...         ...      ...            ...
# 760  16000.0  əlaqəli şəxs   chevrolet    cruze           2015
# 762   7000.0  əlaqəli şəxs   chevrolet     aveo           2010
# 763   7200.0  əlaqəli şəxs  lada (vaz)     niva           2012
# 764   5800.0  əlaqəli şəxs        opel   vectra           1997
# 765   8400.0  əlaqəli şəxs  lada (vaz)     2107           2010
#
#             ban_növü         rəng   yürüş sürətlər_qutusu ötürücü  \
# 0              sedan          ağ   336500        avtomat      ön
# 1    offroader / suv          ağ   187000        avtomat      ön
# 2    offroader / suv         göy   145000        avtomat      ön
# 3            hetçbek      gümüşü   290000       mexaniki      ön
# 4              sedan  yaş asfalt   161000        avtomat      ön
# ..               ...          ...     ...             ...     ...
# 760            sedan         qara   71662        avtomat      ön
# 762            sedan          ağ   211000       mexaniki      ön
# 763  offroader / suv          ağ   173000       mexaniki     tam
# 764          hetçbek          ağ   480000        avtomat      ön
# 765            sedan  yaş asfalt    49400       mexaniki    arxa
#
#      mühərrik_hecmi  mühərrik_gucu yanacaq_novu  kredit   yenilendi  \
# 0               2.0            200       benzin   xeyr   27.09.2023
# 1               2.0            184        dizel   xeyr   23.08.2023
# 2               2.0            184        dizel   xeyr   08.08.2023
# 3               1.4             90       benzin   xeyr   08.08.2023
# 4               2.0            249       benzin   xeyr   08.08.2023
# ..              ...            ...          ...     ...         ...
# 760             1.4            140       benzin   xeyr   11.04.2023
# 762             1.4            101       benzin   xeyr   11.04.2023
# 763             1.7             80       benzin   xeyr   11.04.2023
# 764             1.8            115       benzin   xeyr   11.04.2023
# 765             1.6             75       benzin   xeyr   11.04.2023
#
#         vuruğu_var     rənglənib lehimli_disk  abs lyuk yağış_sensoru  \
# 0    vuruğu yoxdur  rənglənməyib          var  var  var           yox
# 1    vuruğu yoxdur  rənglənməyib          var  var  yox           yox
# 2    vuruğu yoxdur  rənglənməyib          var  var  yox           var
# 3    vuruğu yoxdur  rənglənməyib          var  yox  yox           var
# 4    vuruğu yoxdur  rənglənməyib          var  var  var           var
# ..             ...           ...          ...  ...  ...           ...
# 760  vuruğu yoxdur  rənglənməyib          var  var  yox           var
# 762  vuruğu yoxdur     rənglənib          var  var  yox           yox
# 763  vuruğu yoxdur     rənglənib          var  yox  yox           yox
# 764  vuruğu yoxdur     rənglənib          var  var  var           yox
# 765  vuruğu yoxdur  rənglənməyib          yox  yox  yox           var
#
#     mərkəzi_qapanma park_radarı kondisioner oturacaqların_isidilməsi  \
# 0               var         yox         var                      var
# 1               var         var         var                      var
# 2               var         var         var                      var
# 3               var         yox         var                      yox
# 4               var         var         var                      var
# ..              ...         ...         ...                      ...
# 760             var         var         var                      yox
# 762             yox         yox         yox                      yox
# 763             yox         yox         yox                      yox
# 764             yox         yox         yox                      yox
# 765             yox         yox         yox                      yox
#
#     dəri_salon ksenon_lampalar  arxa_görüntü_kamerası  yan_pərdələr  \
# 0          var             yox                    NaN           NaN
# 1          var             yox                    NaN           NaN
# 2          yox             var                    NaN           NaN
# 3          var             yox                    NaN           NaN
# 4          var             var                    NaN           NaN
# ..         ...             ...                    ...           ...
# 760        var             yox                    NaN           NaN
# 762        yox             yox                    NaN           NaN
# 763        yox             var                    NaN           NaN
# 764        yox             yox                    NaN           NaN
# 765        yox             var                    NaN           NaN
#
#      oturacaqların_ventilyasiyası
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ..                            ...
# 760                           NaN
# 762                           NaN
# 763                           NaN
# 764                           NaN
# 765                           NaN
#
# [1246 rows x 30 columns]

# %%
df.to_csv('soldout.csv',index=False)
